# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %%
df = pd.read_csv("./movies.csv")

# %%
df_sorted = df.sort_values(by='score', ascending=False)
top20 = df_sorted.head(20)
total_data = len(top20)

# %%
plt.figure(figsize=(10, 10))
# sns.barplot(x='score', y='name', data=top20, palette='viridis')
cmap = cmap = mcolors.LinearSegmentedColormap.from_list('custom_cmap', ['teal','yellow','red'], N=total_data)

bar_plot = sns.barplot(x='score', y='name', data=top20, palette=cmap(range(total_data)))
# bar_plot = sns.barplot(x='score', y='name', data=top20, palette="viridis")

# Menambahkan anotasi
for index, value in enumerate(top20['score']):
    bar_plot.text(value, index, f'{value:.1f}', color='black', ha="left", va='center')

# Memberikan label dan judul
plt.xlabel('Rating', fontsize='12')
plt.ylabel('Title', fontsize='12')
plt.title('Top 20 Movies by IMDb Rating')
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)

# plt.tight_layout() pakai ini biar terlihat rapi, tetapi saat plotnya disimpan akan terlihat sulit dibaca

# Menampilkan plot
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12984\2195031599.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x='score', y='name', data=top20, palette=cmap(range(total_data)))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12984\2195031599.py:5: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
#   bar_plot = sns.barplot(x='score', y='name', data=top20, palette=cmap(range(total_data)))
